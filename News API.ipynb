# %%
pip install newsapi-python
# Out:
# Requirement already satisfied: newsapi-python in c:\users\vella\anaconda3\lib\site-packages (0.2.6)
# Requirement already satisfied: requests<3.0.0 in c:\users\vella\anaconda3\lib\site-packages (from newsapi-python) (2.28.1)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\vella\anaconda3\lib\site-packages (from requests<3.0.0->newsapi-python) (2.8)
# Requirement already satisfied: charset-normalizer<3,>=2 in c:\users\vella\anaconda3\lib\site-packages (from requests<3.0.0->newsapi-python) (2.1.1)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\vella\anaconda3\lib\site-packages (from requests<3.0.0->newsapi-python) (2019.6.16)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in c:\users\vella\anaconda3\lib\site-packages (from requests<3.0.0->newsapi-python) (1.25.11)
# Note: you may need to restart the kernel to use updated packages.

# %%
from newsapi.newsapi_client import NewsApiClient
import json
import pandas as pd
# Out:
# C:\Users\vella\Anaconda3\lib\site-packages\pandas\compat\_optional.py:138: UserWarning: Pandas requires version '2.7.0' or newer of 'numexpr' (version '2.6.9' currently installed).
#   warnings.warn(msg, UserWarning)

# %%
keywords = input('Enter the word for search: ').split()
# Out:
# Enter the word for search: tesla

# %%
for word in keywords:
     api = NewsApiClient(api_key="a631f8a47c8a4e7c886b877bffabf138")
     result = api.get_everything(word, sort_by="publishedAt", language="en")
     print(result)
# Out:
# {'status': 'ok', 'totalResults': 12777, 'articles': [{'source': {'id': None, 'name': 'Biztoc.com'}, 'author': 'newsweek.com', 'title': 'Amazon Alexa to allow voice-initiated electric vehicle charging', 'description': 'Amazon will partner with EVgo later this year to offer voice-enabled electric vehicle (EV) charging via its Amazon Alexa technology. EVgo is the first charging network to partner with Amazon to use Alexa for this purpose. The news comes as more automakers are…', 'url': 'https://biztoc.com/x/5b46e91d142bc993', 'urlToImage': 'https://c.biztoc.com/p/5b46e91d142bc993/og.webp', 'publishedAt': '2023-01-05T14:02:05Z', 'content': 'Amazon will partner with EVgo later this year to offer voice-enabled electric vehicle (EV) charging via its Amazon Alexa technology. EVgo is the first charging network to partner with Amazon to use A… [+427 chars]'}, {'source': {'id': None, 'name': 'Digital Trends'}, 'author': 'Stephen Edelstein', 'title': 'Amazon Alexa aims to streamline the EV charging experience', 'description': 'Drivers will be able to ask Amazon Alexa for EV charging locations beginning later in 2023.', 'url': 'https://www.digitaltrends.com/cars/amazon-alexa-for-ev-charging-unveiled-at-ces-2023/', 'urlToImage': 'https://www.digitaltrends.com/wp-content/uploads/2023/01/Amazon-Alexa-for-EV-charging.jpeg?resize=1200%2C630&p=1', 'publishedAt': '2023-01-05T14:00:51Z', 'content': 'Skip to main content\r\nWhile the number of EV charging stations continues to grow, finding a station and paying for charging can still be a hassle. But soon you’ll be able to simply ask Alexa.\r\nAt CES… [+2258 chars]'}, {'source': {'id': 'newsweek', 'name': 'Newsweek'}, 'author': 'Eileen Falkenberg-Hull', 'title': 'Amazon Alexa To Allow Voice-initiated Electric Vehicle Charging', 'description': 'Amazon Alexa voice technology will allow users to find and navigate to an EVgo charger.', 'url': 'https://www.newsweek.com/amazon-alexa-allow-voice-initiated-electric-vehicle-charging-1770504', 'urlToImage': 'https://d.newsweek.com/en/full/2172387/ford-amazon-alexa-screen-prompt.jpg', 'publishedAt': '2023-01-05T14:00:01Z', 'content': 'Amazon will partner with EVgo later this year to offer voice-enabled electric vehicle (EV) charging via its Amazon Alexa technology. EVgo is the first charging network to partner with Amazon to use A… [+3299 chars]'}, {'source': {'id': None, 'name': 'SlashGear'}, 'author': 'staff@slashgear.com (Quentyn Kennemer)', 'title': 'Alexa Will Soon Help You Find And Pay For EV Charging', 'description': 'EVgo is partnering up with Amazon to utilize Echo Auto and Alexa to help identify and pay for charging at thousands of EVgo charging stations in the U.S.', 'url': 'https://www.slashgear.com/1156430/alexa-will-soon-help-you-find-and-pay-for-ev-charging/', 'urlToImage': 'https://www.slashgear.com/img/gallery/alexa-will-soon-help-you-find-and-pay-for-ev-charging/l-intro-1672857090.jpg', 'publishedAt': '2023-01-05T14:00:00Z', 'content': 'The Alexa-enabled EV charging experience will tap into PlugShare and EVgo Inside, allowing customers to find nearby charging stations, initiate a charging session, and complete payment, all with Alex… [+1221 chars]'}, {'source': {'id': None, 'name': 'CNBC'}, 'author': 'John Rosevear', 'title': "Amazon's Alexa will soon help EV drivers find a charger", 'description': 'Amazon is teaming up with EVGo, one of the largest U.S. EV charging networks, to add new EV-related features to Alexa.', 'url': 'https://www.cnbc.com/2023/01/05/amazons-alexa-will-soon-help-ev-drivers-find-a-charger.html', 'urlToImage': 'https://image.cnbcfm.com/api/v1/image/107174101-1672867673275-Alexa-for-EV-Charging.jpg?v=1672927201&w=1920&h=1080', 'publishedAt': '2023-01-05T14:00:00Z', 'content': "Amazon is betting that Alexa, its voice-activated virtual assistant, can help ease one of electric vehicle drivers' biggest worries: finding a charging station while on the road.\r\nAt CES on Thursday,… [+1386 chars]"}, {'source': {'id': None, 'nam ...

# %%
news_source=[]
title=[]
url = []
description = []
date =[]


for articles in result['articles']:
  news_source.append(articles['source']['name'])
  title.append(articles['title'])
  url.append(articles['url'])
  description.append(articles['description'])
  date.append(articles['publishedAt'])

# %%
data = {'News_source': news_source,'Title':title,'Url':url,'Description':description,'Date':date}
df = pd.DataFrame(data)

# %%
df
# Out:
#        News_source                                              Title  \
# 0       Biztoc.com  Amazon Alexa to allow voice-initiated electric...
# 1   Digital Trends  Amazon Alexa aims to streamline the EV chargin...
# 2         Newsweek  Amazon Alexa To Allow Voice-initiated Electric...
# 3        SlashGear  Alexa Will Soon Help You Find And Pay For EV C...
# 4             CNBC  Amazon's Alexa will soon help EV drivers find ...
# ..             ...                                                ...
# 95       Digitimes  Sony and Honda unveil Afeela EV in latest chal...
# 96         Sky.com  NI secretary becomes second cabinet minister t...
# 97      Biztoc.com  Crypto Analyst Who Nailed 2018 Bitcoin Bottom ...
# 98  The Daily Hodl  Crypto Analyst Who Nailed 2018 Bitcoin Bottom ...
# 99   Seeking Alpha  2023 Comes In Like An Ongoing Bear For Stocks ...
#
#                                                   Url  \
# 0               https://biztoc.com/x/5b46e91d142bc993
# 1   https://www.digitaltrends.com/cars/amazon-alex...
# 2   https://www.newsweek.com/amazon-alexa-allow-vo...
# 3   https://www.slashgear.com/1156430/alexa-will-s...
# 4   https://www.cnbc.com/2023/01/05/amazons-alexa-...
# ..                                                ...
# 95  https://www.digitimes.com/news/a20230105VL211/...
# 96  https://news.sky.com/story/northern-ireland-se...
# 97              https://biztoc.com/x/6b2ee8bef9e8dc8e
# 98  https://dailyhodl.com/2023/01/05/crypto-analys...
# 99  https://seekingalpha.com/article/4567959-2023-...
#
#                                           Description                  Date
# 0   Amazon will partner with EVgo later this year ...  2023-01-05T14:02:05Z
# 1   Drivers will be able to ask Amazon Alexa for E...  2023-01-05T14:00:51Z
# 2   Amazon Alexa voice technology will allow users...  2023-01-05T14:00:01Z
# 3   EVgo is partnering up with Amazon to utilize E...  2023-01-05T14:00:00Z
# 4   Amazon is teaming up with EVGo, one of the lar...  2023-01-05T14:00:00Z
# ..                                                ...                   ...
# 95  Sony Honda Mobility Inc. said its electric veh...  2023-01-05T08:54:32Z
# 96  Northern Ireland Secretary Chris Heaton-Harris...  2023-01-05T08:11:00Z
# 97  A popular crypto trader known for accurately c...  2023-01-05T08:08:04Z
# 98  A popular crypto trader known for accurately c...  2023-01-05T08:04:36Z
# 99  2023 has come in like an ongoing bear for stoc...  2023-01-05T08:00:00Z
#
# [100 rows x 5 columns]

# %%
b5bb23a524ff49eab93bf121027c9bb8
